# %% [markdown]
# <a href="https://colab.research.google.com/github/catherinel04/MIT_AI_Studio/blob/Catherine_Liu_BTT/Maka_model_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.16.3)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.38.post1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (3.1.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.5)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.6)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (24.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.44.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.4.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (10.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=0.4.1->bertopic) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=0.4.1->bertopic) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=0.4.1->bertopic) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
from wordcloud import WordCloud
import re
import ast
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
from bertopic import BERTopic
from bertopic.representation import MaximalMarginalRelevance
from sentence_transformers import SentenceTransformer, util
from yellowbrick.cluster import KElbowVisualizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import random
from random import seed, choice
import warnings
warnings.filterwarnings("ignore")

# %%
def pre_process(df:pd.DataFrame, var:str, method:str) -> pd.DataFrame:
    df = treat_missing(df, var, method)
    df = regular_expression(df, var)
    df = remove_stopwords(df, var)
    return df
def treat_missing(df:pd.DataFrame, var:str, method:str):
    df[var] = df[var].fillna(method)
    return df
def regular_expression(df:pd.DataFrame, var:str) -> pd.DataFrame:
    # Remove dots, commas, numbers ... from the review text
    for i in range(len(df)):
        df[var].iloc[i] = re.sub(r'[0-9].', ' ', df[var].iloc[i]).lower().replace('?','').replace(',','').replace('.','').replace('!','').replace('-','').replace('(','').replace(')','').lstrip().rstrip()
    return df
def remove_stopwords(df:pd.DataFrame, var:str) -> pd.DataFrame:
    # Stopwods from nltk
    stop = stopwords.words('english')
    # Remove stopwords
    df[var] = df[var].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
    return df
def check_unique(df:pd.DataFrame, var:str) -> int:
    nunique = df[var].nunique()
    print(nunique)
    if nunique < 10:
        print(df[var].unique())
def word_cloud(col):
    text = ' '.join(col)
    wordcloud = WordCloud().generate(text)
    print(f'Top freq words: {list(wordcloud.words_.keys())}')
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.title("Wordcloud for the Amazon Reviews")
    plt.show()
def topic_bert(col,diversity):
    representation_model = MaximalMarginalRelevance(diversity=0.5)
    topic_model = BERTopic(representation_model=representation_model)
    topics,probs = topic_model.fit_transform(col)
    top_words = topic_model.get_topic_info()
    print(top_words['Representation'])
    return topic_model
def clustering_fast(df, var, min_community_size, threshold):
    clusters = util.community_detection(df1[var], min_community_size=min_community_size, threshold=threshold)
    clusters = pd.DataFrame({'sentence_ids': clusters})
    df_exploded = clusters.explode('sentence_ids')
    df_exploded['clusters_fast'] = df_exploded.index
    df_exploded.set_index('sentence_ids', inplace=True)
    df = df.merge(df_exploded, left_index=True, right_index=True)
    return df

# %%
# Read the data and display the dataset
df = pd.read_csv('/7817_1.csv')
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'dateAdded',
#        'dateUpdated', 'dimension', 'ean', 'keys', 'manufacturer',
#        'manufacturerNumber', 'name', 'prices', 'reviews.date',
#        'reviews.doRecommend', 'reviews.numHelpful', 'reviews.rating',
#        'reviews.sourceURLs', 'reviews.text', 'reviews.title',
#        'reviews.userCity', 'reviews.userProvince', 'reviews.username', 'sizes',
#        'upc', 'weight'],
#       dtype='object')

# %% [markdown]
# # 1. EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1597 entries, 0 to 1596
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1597 non-null   object
#  1   asins                 1597 non-null   object
#  2   brand                 1597 non-null   object
#  3   categories            1597 non-null   object
#  4   colors                774 non-null    object
#  5   dateAdded             1597 non-null   object
#  6   dateUpdated           1597 non-null   object
#  7   dimension             565 non-null    object
#  8   ean                   898 non-null    float64
#  9   keys                  1597 non-null   object
#  10  manufacturer          965 non-null    object
#  11  manufacturerNumber    902 non-null    object
#  12  name                  1597 non-null   object
#  13  prices                1597 non-null   object
#  14  reviews.date          1217 non-null   object
#  15  reviews.doRecommend   539 non-null    object
#  16  reviews.numHelpful    900 non-null    float64
#  17  reviews.rating        1177 non-null   float64
#  18  reviews.sourceURLs    1597 non-null   object
#  19  reviews.text          1597 non-null   object
#  20  reviews.title         1580 non-null   object
#  21  reviews.userCity      0 non-null      float64
#  22  reviews.userProvince  0 non-null      float64
#  23  reviews.username      1580 non-null   object
#  24  sizes                 0 non-null      float64
#  25  upc                   898 non-null    float64
#  26  weight                686 non-null    object
# dtypes: float64(7), object(20)
# memory usage: 337.0+ KB

# %%
df[['name','prices','reviews.rating','reviews.title','reviews.text','reviews.userCity','reviews.userProvince','sizes','weight']].head()
# Out:
#                 name                                             prices  \
# 0  Kindle Paperwhite  [{"amountMax":139.99,"amountMin":139.99,"curre...
# 1  Kindle Paperwhite  [{"amountMax":139.99,"amountMin":139.99,"curre...
# 2  Kindle Paperwhite  [{"amountMax":139.99,"amountMin":139.99,"curre...
# 3  Kindle Paperwhite  [{"amountMax":139.99,"amountMin":139.99,"curre...
# 4  Kindle Paperwhite  [{"amountMax":139.99,"amountMin":139.99,"curre...
#
#    reviews.rating                               reviews.title  \
# 0             5.0              Paperwhite voyage, no regrets!
# 1             5.0           One Simply Could Not Ask For More
# 2             4.0  Great for those that just want an e-reader
# 3             5.0                    Love / Hate relationship
# 4             5.0                                   I LOVE IT
#
#                                         reviews.text  reviews.userCity  \
# 0  I initially had trouble deciding between the p...               NaN
# 1  Allow me to preface this with a little history...               NaN
# 2  I am enjoying it so far. Great for reading. Ha...               NaN
# 3  I bought one of the first Paperwhites and have...               NaN
# 4  I have to say upfront - I don't like coroporat...               NaN
#
#    reviews.userProvince  sizes     weight
# 0                   NaN    NaN  205 grams
# 1                   NaN    NaN  205 grams
# 2                   NaN    NaN  205 grams
# 3                   NaN    NaN  205 grams
# 4                   NaN    NaN  205 grams

# %%
check_unique(df, 'weight')
# Out:
# 9
# ['205 grams' '1.1 pounds' nan '1.6 ounces' '1.75 lbs' '0.8 ounces'
#  '4 ounces' '5 ounces' '4.6 ounces' '2.4 ounces']

# %%
check_unique(df, 'brand')
# Out:
# 2
# ['Amazon' 'Moshi']

# %%
check_unique(df, 'name')
# Out:
# 62

# %%
check_unique(df, 'categories')
# Out:
# 19

# %%
check_unique(df, 'colors')
# Out:
# 3
# [nan 'GB' 'Black' 'Clear']

# %%
# product frequency by descending order
top_names = df.groupby('name') \
.agg(count=('name','count')
    , avg_rating=('reviews.rating','mean')
    ) \
.sort_values(by='count', ascending=False) \
.reset_index('name')

top_names
# Out:
#                                                  name  count  avg_rating
# 0   Amazon Tap - Alexa-Enabled Portable Bluetooth ...    542    4.533210
# 1                                      Amazon Fire TV    166    4.204545
# 2                           Amazon Premium Headphones    133    4.012987
# 3                                    Fire HD 6 Tablet     87    5.000000
# 4                                  Kindle Fire HDX 7"     70    4.391304
# ..                                                ...    ...         ...
# 57                           Fire Kids Edition Tablet      3    2.666667
# 58                                Fire HDX 8.9 Tablet      3    4.333333
# 59                        Fire HD 8 Tablet with Alexa      3    4.666667
# 60                                   Fire HD 8 Tablet      3    3.666667
# 61  Certified Refurbished Kindle Paperwhite E-read...      3    5.000000
#
# [62 rows x 3 columns]

# %%
sns.histplot(df['reviews.rating'])
# Out:
# <Axes: xlabel='reviews.rating', ylabel='Count'>

# %%
list(top_names.name.head())
# Out:
# ['Amazon Tap - Alexa-Enabled Portable Bluetooth Speaker',
#  'Amazon Fire TV',
#  'Amazon Premium Headphones',
#  'Fire HD 6 Tablet',
#  'Kindle Fire HDX 7"']

# %%
sns.histplot(df.merge(top_names.head(), on='name', how='inner'), x='reviews.rating', hue='name')
# Out:
# <Axes: xlabel='reviews.rating', ylabel='Count'>

# %%
# create additional variables
df['title_text'] = df['reviews.title'] + df['reviews.text']
df[['title_text','reviews.title','reviews.text']]
# Out:
#                                              title_text  \
# 0     Paperwhite voyage, no regrets!I initially had ...
# 1     One Simply Could Not Ask For MoreAllow me to p...
# 2     Great for those that just want an e-readerI am...
# 3     Love / Hate relationshipI bought one of the fi...
# 4     I LOVE ITI have to say upfront - I don't like ...
# ...                                                 ...
# 1592  I would be disappointed with myself if i produ...
# 1593  Battery draining remote!!!!I have had to chang...
# 1594  replacing an even worse remote. Waste of timeR...
# 1595  OverpricedIt does the job but is super over pr...
# 1596  I am sending all of this crap back to amazon a...
#
#                                           reviews.title  \
# 0                        Paperwhite voyage, no regrets!
# 1                     One Simply Could Not Ask For More
# 2            Great for those that just want an e-reader
# 3                              Love / Hate relationship
# 4                                             I LOVE IT
# ...                                                 ...
# 1592  I would be disappointed with myself if i produ...
# 1593                        Battery draining remote!!!!
# 1594      replacing an even worse remote. Waste of time
# 1595                                         Overpriced
# 1596  I am sending all of this crap back to amazon a...
#
#                                            reviews.text
# 0     I initially had trouble deciding between the p...
# 1     Allow me to preface this with a little history...
# 2     I am enjoying it so far. Great for reading. Ha...
# 3     I bought one of the first Paperwhites and have...
# 4     I have to say upfront - I don't like coroporat...
# ...                                                 ...
# 1592  This is not the same remote that I got for my ...
# 1593  I have had to change the batteries in this rem...
# 1594  Remote did not activate, nor did it connect to...
# 1595  It does the job but is super over priced. I fe...
# 1596  I ordered this item to replace the one that no...
#
# [1597 rows x 3 columns]

# %%
# pre-process data
df1 = df.copy()
df1 = pre_process(df1, 'reviews.text', 'NA')
df1 = pre_process(df1, 'title_text', 'NA')

# %%
# word cloud
word_cloud(df1['reviews.text'])
# Out:
# Top freq words: ['kindle fire', 'fire hd', 'fire tv', 'app', 'last year', 'tap', 'echo', 'love', 'one', 'fire hdx', 'amazon', 'alexa', 'case', 'amazon prime', 'apple buds', 'great', 'apple tv', 'time', 'say', 'sound quality', 'speaker', 'problem', 'cover', 'going fall', 'tangle free', 'year kindle', 'ipad mini', 'prime content', 'year model', 'netflix', 'read', 'back', 'voice search', 'need', 'set headphones', 'kindle keyboard', 'lows mids', 'battery life', 'noise cancelling', 'early reviews', 'day', 'paperwhite', 'magnets tangle', 'prime movie', 'ipad ipad', 'without', 'got', 'phone', 'make sure', 'sound great', 'game', 'new kindle', 'tv show', 'going around', 'purchased', 'free cord', 'write review', 'still', 'reading book', 'music', 'seem', 'little', 'wifi', 'already', 'think amazon', 'star rating', 'add', 'people saying', 'bluetooth speaker', 'never owned', 'another', 'liked much', 'good product', 'portable', 'prime member', 'bad reviews', 'slightly better', 'nice set', 'echo dot', 'biggest complaint', 'price range', 'still hear', 'easy use', 'able compare', 'much used', 'samsung note', 'full sound', 'kindle paperwhite', 'easy find', 'used year', 'better apple', 'seen good', 'headphones sound', 'purchased item', 'feel people', 'fire gen', 'items amazon', 'bit better', 'never seen', 'actually sound', 'google', 'amazon tap', 'second generation', 'amazon years', 'years rarely', 'rarely write', 'reviews felt', 'felt compelled', 'compelled write', 'write one', 'one although', 'although reviews', 'reviews point', 'point never', 'hoping people', 'people purchase', 'purchase star', 'rating accurate', 'accurate product', 'address three', 'three biggest', 'read others', 'quality think', 'think headphones', 'owned expensive', 'expensive pair', 'compare higherend', 'higherend offerings', 'owned dozens', 'dozens cheap', 'cheap midrange', 'midrange headphones', 'headphones range', 'audiophile musician', 'missing something', 'something coming', 'fine ignorance', 'buds liked', 'years recently', 'recently using', 'using redesigned', 'redesigned ones', 'ones year', 'tinny listening', 'listening sound', 'alltoocommon headphones', 'headphones price', 'range far', 'far people', 'saying compare', 'compare apple', 'buds well', 'well know', 'know maybe', 'maybe crazy', 'crazy exclusive', 'exclusive version', 'version apple', 'buds amazing', 'amazing compared', 'compared regular', 'regular earpods', 'earpods think', 'amazon headphones', 'headphones actually', 'sound bit', 'better provide', 'provide nice', 'nice full', 'sound represent', 'represent highs', 'highs lows', 'mids equally', 'equally well', 'well mainly', 'mainly listening', 'people complained', 'complained falling', 'falling feeling', 'fall ears', 'validity although', 'although obviously', 'obviously depends', 'depends specific', 'specific ears', 'ears feel', 'fall give', 'give cord', 'cord tug', 'tug stay', 'stay secure', 'secure apple', 'apple budsread', 'fast', 'others sound', 'listening metalfit', 'metalfit feel', 'bought', 'issue', 'casual user']

# %% [markdown]
# # 2. BERTopic

# %%
# with reviews.text only
topic_model1 = topic_bert(df1['reviews.text'],0.5)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 0     [kindle, models, accessed, new, screen, keyboa...
# 1     [echo, tap, alexa, bluetooth, sound, portable,...
# 2     [prime, search, amazon, netflix, roku, watch, ...
# 3     [cover, cases, fire, screen, protectors, kindl...
# 4     [fire, tablet, setup, price, video, firsttime,...
# 5     [earbuds, magnets, headphones, designed, noise...
# 6     [apples, theyre, reviews, headphones, range, c...
# 7     [roku, box, apple, features, channels, wdtv, c...
# 8     [earpods, bass, try, skullcandy, cables, timea...
# 9     [secondary, reviews, ereader, touch, vehicle, ...
# 10    [kindle, books, physical, pageturns, smort, pa...
# 11    [camera, gigs, dual, quality, tablet, havei, g...
# 12    [samsung, fire, note, kindles, generation, bac...
# 13    [replacement, batteries, months, stick, fire, ...
# 14    [refurbished, device, suede, leather, problem,...
# 15    [kindle, books, oasis, page, paperwhite, easie...
# 16    [comcast, ondemand, watchrent, middleaged, mea...
# 17    [dot, case, echo, look, mundane, disk, readjus...
# 18    [paperwhite, pixels, generation, kindle, ppi, ...
# 19    [movies, kids, saysjuly, dallas, primeonly, re...
# 20    [hdx, blue, leds, kindle, updated, display, ne...
# 21    [tablet, apps, freetime, books, access, would,...
# 22    [apples, buds, theyre, reviews, sound, headpho...
# 23    [keyboard, kindle, reading, screen, wifi, lit,...
# 24    [kindle, saysoctober, hd, fire, point, device,...
# 25    [hdx, surfing, media, assumption, may, inthis,...
# 26    [ipad, years, kindle, use, hdx, spreadsheet, s...
# 27    [include, micro, usb, buttonsonly, tableti, ch...
# 28    [kindle, fire, year, also, reviewmy, hzread, l...
# 29    [fan, covers, plastic, looks, dot, colorsedit,...
# 30    [controller, aa, energizer, duracell, drain, p...
# 31    [buttons, kindle, odd, folders, baggage, feest...
# 32    [videos, free, hdx, limitationsprime, qualityt...
# 33    [sling, rubber, speaker, silicone, dock, prote...
# 34    [paperwhite, page, worth, shadows, frontlighti...
# Name: Representation, dtype: object

# %%
# with reviews.text and title
topic_model2 = topic_bert(df1['title_text'],0.5)
# Out:
# 0     [kindle, read, screen, keyboard, device, roku,...
# 1     [tap, echo, alexa, portable, sound, bluetooth,...
# 2     [apples, buds, theyre, headphones, reviews, ra...
# 3     [cover, stand, fire, protect, cases, kindle, c...
# 4     [batteries, controller, replacement, months, w...
# 5     [dots, fan, fabric, grey, covers, fit, pop, ec...
# 6     [earbuds, magnets, headphones, designed, noise...
# 7     [kindle, keyboard, read, light, models, paperw...
# 8     [roku, apple, streaming, features, boxes, remo...
# 9     [camera, gigs, dual, hd, tablet, quality, inte...
# 10    [fire, tablet, setup, price, consistent, updat...
# 11    [prime, search, games, amazon, free, well, net...
# 12    [earpods, bass, try, danglingread, preordered,...
# 13    [immediate, secondary, response, reviews, erea...
# 14    [fire, samsung, kindles, tablets, generation, ...
# 15    [netflix, amazons, xbox, cable, roku, flixster...
# 16    [comcast, watchrent, middleaged, meansso, tech...
# 17    [refurbished, cover, problems, called, kindles...
# 18    [hdx, blue, leds, kindle, glow, edges, nexus, ...
# 19    [genre, kids, tv, dallas, saysjuly, primeonly,...
# 20    [apps, tablet, freetime, parent, lock, screen,...
# 21    [na, , , , , , , , , , , , , , , , , , , , , ,...
# 22    [ipad, kindle, fire, year, also, laptopsi, ben...
# 23    [charger, ppi, resolution, new, kindles, paget...
# 24    [amazoncom, kindle, hd, saysoctober, device, f...
# 25    [hdx, capacity, media, save, assumption, may, ...
# 26    [five, supplied, starsall, starsperfect, overp...
# 27    [paperwhite, pixels, voyage, lighting, pages, ...
# 28    [ipad, hd, year, kindle, tablet, use, devicefe...
# 29    [gamer, remote, return, fire, stick, batteries...
# 30    [include, micro, tablet, usb, computerdisplay,...
# 31    [books, kindle, paperwhite, youll, backlight, ...
# 32    [titles, videos, watch, hdxthe, primeread, qua...
# 33    [protectors, screen, moshi, bubbles, antiglare...
# 34    [paperwhite, worth, ounces, cover, eink, upgra...
# Name: Representation, dtype: object

# %%
topic_model1.visualize_barchart(top_n_topics=8,n_words=9)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31dbbcaa-3035-4f8b-ad24-0dd2283e9360" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31dbbcaa-3035-4f8b-ad24-0dd2283e9360")) {                    Plotly.newPlot(                        "31dbbcaa-3035-4f8b-ad24-0dd2283e9360",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015767564127231792,0.017586045144145326,0.01899590217931407,0.021398287607616476,0.021435015534839248,0.021658746428827255,0.042943062882157414,0.04444241555243302,0.05272681500591363],"y":["button  ","dot  ","voice  ","portable  ","sound  ","bluetooth  ","alexa  ","tap  ","echo  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013887333826863912,0.014077535100108462,0.014698074495790425,0.015063572959879385,0.017847259804483564,0.025216630380052833,0.02747871429271701,0.03414885657510187,0.03726866570844741],"y":["well  ","remote  ","apps  ","watch  ","roku  ","netflix  ","amazon  ","search  ","prime  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.014708484292664912,0.016796399840073237,0.01779758262963353,0.020113487619841584,0.020528933137867286,0.020749451853756318,0.020994496920111853,0.02284374246150662,0.05532760434922835],"y":["portrait  ","origami  ","great  ","kindle  ","protectors  ","screen  ","fire  ","cases  ","cover  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.015745183057131566,0.0159053797402403,0.01614359458901685,0.01772049506316372,0.017812492345229174,0.0180777191889698,0.025008448269338096,0.02949768366859188,0.04273492995820265],"y":["hdx  ","updates  ","crashes  ","firsttime  ","video  ","price  ","setup  ","tablet  ","fire  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0414497126376667,0.05199899532893421,0.052452948888548026,0.0662393663028742,0.06626132586477723,0.06862374066397597,0.08541787530192287,0.10067110526254157,0.1008225432307534],"y":["cord  ","flat  ","cancelling  ","tangle  ","noise  ","designed  ","headphones  ","magnets  ","earbuds  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02577907962606656,0.025882993937033857,0.03262042203293695,0.03693176810658774,0.04106304852230969,0.04361584348750037,0.046770501043882015,0.05235213394862591,0.05639403722417445],"y":["budsread  ","metalfit  ","ears  ","compare  ","range  ","headphones  ","reviews  ","theyre  ","apples  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.017013652973730354,0.017447898179755568,0.01815266580590287,0.019076149789202315,0.023527060573687884,0.029908414116202098,0.044065987925231906,0.06250638411309505,0.07110137640196673],"y":["see  ","interface  ","chromecast  ","wdtv  ","channels  ","features  ","apple  ","box  ","roku  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03205761476529825,0.03205761476529825,0.03205761476529825,0.03205761476529825,0.03247992161538434,0.03290380327126858,0.04249816352973781,0.05353027272111203,0.06674064060884123],"y":["androidsi  ","headphoneslooks  ","orderingi  ","timeaudio  ","cables  ","skullcandy  ","try  ","bass  ","earpods  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %%
topic_model2.visualize_barchart(top_n_topics=8,n_words=9)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f4770363-f17b-4a54-a485-c2f480179b2a" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4770363-f17b-4a54-a485-c2f480179b2a")) {                    Plotly.newPlot(                        "f4770363-f17b-4a54-a485-c2f480179b2a",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013658821188674087,0.015329191887033994,0.017005589750151023,0.020574227889930647,0.021277407043567342,0.021714426058413658,0.03807161691218345,0.04793576320328061,0.048903272723037565],"y":["button  ","dot  ","voice  ","bluetooth  ","sound  ","portable  ","alexa  ","echo  ","tap  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02451232795234635,0.03521919072667817,0.03643979856277162,0.03908176697316466,0.04488369664921581,0.04874168817696764,0.049975552800650455,0.05067741000404806,0.053849034363137746],"y":["higherend  ","compare  ","fall  ","range  ","reviews  ","headphones  ","theyre  ","buds  ","apples  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01891271131012148,0.019687298551517404,0.020675999428768195,0.021297289307169124,0.022766215872003753,0.024446480033979045,0.02613257204076699,0.04091114246248997,0.064065541022038],"y":["portrait  ","well  ","closed  ","kindle  ","cases  ","protect  ","fire  ","stand  ","cover  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.016047368697702704,0.016869752713896385,0.01734670365679188,0.024461685341403236,0.027144527672860994,0.029381821251877903,0.042367729115229555,0.0649953210422892,0.06840064169545425],"y":["problems  ","energizer  ","remotes  ","shield  ","works  ","months  ","replacement  ","controller  ","batteries  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.02778610361507026,0.03054671063313591,0.030736883488826156,0.03101940745517431,0.0328922244363082,0.04871827498123114,0.07006094107369547,0.07022529045542442,0.08112006644984396],"y":["aestheticsim  ","echo  ","pop  ","fit  ","covers  ","grey  ","fabric  ","fan  ","dots  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.04883552818846592,0.04925633586589241,0.049545097737751106,0.062340923196559914,0.06236816975895047,0.06455298447626208,0.08612094702393475,0.09487692671981994,0.09501754037370388],"y":["flat  ","cancelling  ","shove  ","tangle  ","noise  ","designed  ","headphones  ","magnets  ","earbuds  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.01342201121719479,0.01637927188573286,0.017018733457208574,0.018457551169219176,0.021261962747208495,0.022648926441658113,0.026121625781292703,0.03708499478190216,0.07993554879845922],"y":["dx  ","nook  ","buttons  ","paperwhite  ","models  ","light  ","read  ","keyboard  ","kindle  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01589890789972711,0.015938711582113536,0.021899396088749655,0.022221130172255785,0.026555402463221963,0.027964778711194755,0.040508319474359684,0.041300944167682735,0.06723274659824885],"y":["chromecast  ","refreshed  ","channels  ","remote  ","boxes  ","features  ","streaming  ","apple  ","roku  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...

# %% [markdown]
# # 3. Fast Clustering + Word Cloud

# %%
# Create embeddings
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
df1['embedding'] = df1['reviews.text'].apply(lambda x: model.encode(x))
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
df1['embedding'].head()
# Out:
# 0    [-0.12723465, 0.08694401, 0.18223724, 0.194478...
# 1    [-0.1476811, 0.02914856, 0.029938435, -0.13152...
# 2    [-0.32789266, 0.29943135, 0.007804055, 0.63436...
# 3    [-0.16909659, -0.12992842, -0.21179986, -2.727...
# 4    [-0.123719394, 0.031454958, -0.10860202, -0.22...
# Name: embedding, dtype: object

# %%
# Fast Clustering
df1 = clustering_fast(df1, 'embedding', 20, 0.8)

# %%
# Word cloud by clusters
for i in range(8):
    word_cloud(df1[df1['clusters_fast']==i]['reviews.text'])
# Out:
# Top freq words: ['apple buds', 'going fall', 'say', 'purchased items', 'items amazon', 'amazon years', 'years rarely', 'rarely write', 'write reviews', 'reviews felt', 'felt compelled', 'compelled write', 'write one', 'one although', 'although reviews', 'reviews point', 'point never', 'never seen', 'seen good', 'good product', 'bad reviews', 'hoping people', 'people purchase', 'purchase star', 'star rating', 'rating accurate', 'accurate product', 'address three', 'three biggest', 'biggest complaints', 'read others', 'sound quality', 'quality think', 'think headphones', 'headphones sound', 'sound great', 'never owned', 'owned expensive', 'expensive pair', 'able compare', 'compare higherend', 'higherend offerings', 'owned dozens', 'dozens cheap', 'cheap midrange', 'midrange headphones', 'headphones range', 'audiophile musician', 'missing something', 'something coming', 'fine ignorance', 'slightly better', 'better apple', 'buds liked', 'liked much', 'much used', 'used years', 'years recently', 'recently using', 'using redesigned', 'redesigned ones', 'ones year', 'tinny listening', 'listening sound', 'alltoocommon headphones', 'headphones price', 'price range', 'range far', 'far people', 'people saying', 'saying compare', 'compare apple', 'buds well', 'well know', 'know maybe', 'maybe crazy', 'crazy exclusive', 'exclusive version', 'version apple', 'buds amazing', 'amazing compared', 'compared regular', 'regular earpods', 'earpods think', 'think amazon', 'amazon headphones', 'headphones actually', 'actually sound', 'sound bit', 'bit better', 'better provide', 'provide nice', 'nice full', 'full sound', 'sound represent', 'represent highs', 'highs lows', 'lows mids', 'mids equally', 'equally well', 'well mainly', 'mainly listening', 'feel people', 'people complained', 'complained falling', 'falling feeling', 'fall ears', 'validity although', 'although obviously', 'obviously depends', 'depends specific', 'specific ears', 'ears feel', 'fall give', 'give cord', 'cord tug', 'tug stay', 'stay secure', 'secure apple', 'apple budsread', 'others sound', 'listening metalfit', 'metalfit feel', 'br', 'metalbr', 'fit']
# Top freq words: ['noise cancelling', 'magnets tangle', 'tangle free', 'bought couple', 'wanted earbud', 'earbud designed', 'designed noise', 'cancelling hate', 'hate shove', 'shove headphones', 'headphones brain', 'brain use', 'use apparently', 'apparently lot', 'lot people', 'people assumption', 'assumption supposed', 'supposed noise', 'cancelling something', 'something simple', 'simple earbuds', 'earbuds hate', 'hate able', 'able hear', 'hear going', 'going around', 'around feel', 'feel safe', 'safe public', 'public using', 'using headphones', 'headphones block', 'block everything', 'old style', 'style earbuds', 'earbuds stick', 'stick ears', 'ears comfortable', 'comfortable maybe', 'maybe small', 'small ears', 'ears something', 'never fall', 'fall dislodge', 'dislodge ears', 'ears cancel', 'cancel outside', 'outside noise', 'noise sit', 'sit ears', 'ears exactly', 'exactly supposed', 'supposed sound', 'sound travels', 'travels right', 'free aspects', 'aspects headphones', 'headphones use', 'use headphones', 'headphones work', 'work magnets', 'magnets allow', 'allow hang', 'hang headphones', 'headphones easily', 'easily finished', 'finished flat', 'flat cord', 'cord magnets', 'mean headphones', 'headphones never', 'never really', 'really tangle', 'tangle put', 'put bag', 'bag wherever', 'wherever awesome', 'seems pretty', 'pretty average', 'compare stock', 'stock apple', 'apple iphone', 'iphone earbuds', 'earbuds set', 'set sony', 'sony earbuds', 'earbuds nothing', 'nothing special', 'special lot', 'lot fact', 'fact released', 'released paying', 'paying design', 'design far', 'far magnets', 'magnets ear', 'ear buds', 'buds nice', 'nice flat', 'couple reasonsfirst', 'reasonsfirst wanted', 'right earssecond', 'earssecond really', 'awesome designfinally', 'designfinally sound', 'flat cable', 'cable expect', 'expect perform', 'headphones designed', 'designed perform', 'nice simple', 'simple set', 'set earbuds', 'earbuds sound', 'sound good', 'good people', 'people magnets', 'free cord', 'cord awesome', 'awesome really', 'really quite', 'quite comfortableread', 'comfortableread bought', 'volume', 'google', 'br', 'controls', 'open', 'edit', 'compatible', 'new', 'pixel', 'phones', 'button', 'assitant', 'well', 'controlling', 'every', 'time', 'want', 'change', 'inline', 'assistanti', 'cableread', 'reasonsbr', 'first', 'earsbr', 'second', 'designbr', 'finally']
# Top freq words: ['set headphones', 'nice set', 'still hear', 'volume work', 'work iphones', 'iphones please', 'please iphone', 'iphone research', 'research buying', 'buying eg', 'eg first', 'first line', 'line product', 'product description', 'description work', 'work well', 'wanted give', 'give headphones', 'headphones try', 'try preordered', 'preordered end', 'end june', 'june finally', 'finally came', 'came today', 'today got', 'got try', 'apple earpods', 'earpods headphones', 'headphones ear', 'ear comfortable', 'comfortable chance', 'chance keep', 'keep day', 'minutes hour', 'complete audiophile', 'occasional nice', 'headphones thinking', 'thinking nice', 'headphones even', 'even think', 'pretty similar', 'similar sound', 'sound earpods', 'definitely give', 'give step', 'step apple', 'apple headphones', 'headphones hands', 'thing love', 'love earpods', 'hear everything', 'everything around', 'around headphones', 'headphones way', 'way may', 'think perfect', 'perfect use', 'use around', 'around house', 'house work', 'work even', 'even working', 'fact still', 'hear things', 'things going', 'going around', 'around ambient', 'ambient noise', 'noise loud', 'loud turn', 'want say', 'say far', 'far seem', 'seem good', 'good lows', 'lows mids', 'mids pretty', 'pretty crisp', 'crisp sound', 'sound bass', 'bass bad', 'bad either', 'skullcandy set', 'headphones bass', 'bass honestly', 'honestly better', 'love black', 'black look', 'look tangle', 'tangle free', 'free cord', 'cord nice', 'found interesting', 'interesting section', 'section controls', 'controls regular', 'regular thin', 'thin cables', 'cables make', 'make lighter', 'lighter danglingread', 'well androidsi', 'androidsi wanted', 'try outfeel', 'outfeel feel', 'hour timeaudio', 'think orderingi', 'orderingi guess', 'hands downone', 'downone thing', 'turn volumei', 'volumei want', 'expected headphoneslooks', 'headphoneslooks love', 'danglingread volume', 'br', 'feel', 'guess', 'expected', 'androidsbr', 'outbr', 'timebr', 'audio', 'orderingbr', 'downbr', 'one', 'volumebr', 'headphonesbr']
# Top freq words: ['fire gen', 'samsung note', 'read fire', 'fire tv', 'tv review', 'review know', 'know tough', 'tough amazon', 'amazon comes', 'comes items', 'items needs', 'needs deliver', 'deliver quality', 'quality price', 'price point', 'point earn', 'earn stars', 'stars please', 'please take', 'take time', 'time read', 'read entire', 'entire review', 'review feel', 'feel free', 'free ask', 'ask questions', 'questions best', 'best respond', 'respond update', 'update review', 'review reflect', 'reflect answers', 'answers things', 'things discover', 'discover along', 'along wayfirst', 'wayfirst background', 'background many', 'many amazon', 'amazon kindles', 'kindles bw', 'bw fire', 'gen fire', 'gen well', 'well apple', 'apple ipad', 'ipad gen', 'gen samsung', 'note lg', 'lg g', 'g smartphone', 'smartphone samsung', 'samsung notebooks', 'notebooks chromebooks', 'chromebooks etc', 'used many', 'many products', 'products including', 'including fire', 'fire hdx', 'hdx line', 'line solid', 'solid computer', 'computer background', 'background well', 'well honestly', 'honestly casual', 'casual user', 'user comes', 'comes tablets', 'oneamazon changed', 'changed many', 'many things', 'things life', 'life fire', 'fire product', 'product line', 'line adding', 'adding removing', 'removing features', 'camerasthe first', 'first generation', 'generation one', 'one second', 'second generation', 'generation removed', 'removed backthey', 'backthey useful', 'useful devices', 'devices one', 'one niche', 'niche speak', 'speak make', 'make sure', 'sure whatever', 'features important', 'important younow', 'younow model', 'big smartphonewhich', 'smartphonewhich big', 'big difference', 'difference past', 'past kindles', 'kindles compact', 'compact lighter', 'lighter yet', 'yet still', 'still usable', 'usable fact', 'fact shrinking', 'shrinking size', 'size increases', 'increases usefulness', 'usefulness find', 'find use', 'use smartphone', 'smartphone way', 'way tabletseven', 'tabletseven smaller', 'smaller fire', 'fire hd', 'hd samsung', 'note tablets', 'tablets expecting', 'expecting replace', 'replace couch', 'couch usage', 'usage great', 'much less', 'less expensive', 'expensive smartphones', 'smartphones means', 'means feel', 'feel less', 'less bad', 'bad scratches', 'scratches might', 'might occur', 'occur accidental', 'accidental drops', 'drops guilty', 'guilty bothread', 'bothread read']
# Top freq words: ['early reviews', 'preface saying', 'saying ipad', 'ipad expecting', 'expecting tablet', 'tablet perform', 'perform anywhere', 'anywhere near', 'near level', 'level followed', 'followed early', 'reviews closely', 'closely seeing', 'seeing enough', 'enough satisfied', 'satisfied customers', 'customers figured', 'give kindle', 'kindle fire', 'fire hd', 'hd try', 'try chose', 'chose base', 'base gb', 'gb special', 'special offers', 'offers plan', 'plan use', 'use secondary', 'secondary ereader', 'ereader secondary', 'secondary even', 'even tertiary', 'tertiary vehicle', 'vehicle internet', 'internet access', 'found powerful', 'powerful little', 'little tablet', 'tablet far', 'far completely', 'completely free', 'free bugs', 'bugs laggy', 'laggy speeds', 'speeds mentioned', 'mentioned early', 'reviews fact', 'fact performance', 'performance exceeded', 'exceeded expectations', 'expectations consider', 'consider perhaps', 'perhaps year', 'year best', 'best purchasefirst', 'purchasefirst look', 'look nice', 'nice sleek', 'sleek ordered', 'ordered black', 'black model', 'model though', 'though actually', 'actually quite', 'quite bit', 'bit heavier', 'imagined heavy', 'heavy enough', 'enough considered', 'considered negative', 'negative display', 'display fantastic', 'fantastic quality', 'quality first', 'first big', 'big surprise', 'surprise touch', 'touch screen', 'screen performs', 'performs incredibly', 'incredibly well', 'well point', 'point experienced', 'experienced immediate', 'immediate response', 'response point', 'point say', 'say touch', 'touch response', 'response far', 'far indistinguishable', 'indistinguishable ipad', 'ipad based', 'based early', 'reviews case', 'case quite', 'quite pleasantly', 'pleasantly surprised', 'surprised fire', 'fire user', 'user friendly', 'friendly easy', 'easy intuit', 'intuit feel', 'feel confident', 'confident navigation', 'navigation new', 'new device', 'device immediate', 'immediate onscreen', 'onscreen tutorial', 'tutorial option', 'option skip', 'skip guide', 'guide youi', 'youi first', 'first checked', 'checked ereader', 'ereader function', 'function books', 'books loaded', 'loaded immediately', 'immediately easily', 'easily cloud', 'cloud really', 'functionality readerread']
# Top freq words: ['tablet want', 'dual speakers', 'low price', 'price tablet', 'tablet really', 'really expected', 'expected camera', 'camera great', 'always use', 'use phone', 'phone camera', 'camera effect', 'effect pros', 'pros cons', 'cons pros', 'pros low', 'low cost', 'cost yet', 'yet high', 'high tech', 'tech great', 'great screen', 'screen quality', 'quality course', 'course better', 'better looks', 'looks great', 'great smooth', 'smooth responsive', 'responsive easy', 'easy access', 'access amazon', 'amazon prime', 'prime content', 'content easy', 'easy wirelessly', 'wirelessly share', 'share content', 'content tv', 'tv battery', 'battery life', 'life web', 'web browser', 'browser works', 'works greatcons', 'greatcons apps', 'apps android', 'android users', 'users used', 'used camera', 'camera quality', 'quality great', 'great flash', 'flash less', 'less extra', "extra features'", "features' higher", 'higher priced', 'priced tablets', 'tablets havei', 'havei opted', 'opted go', 'go gb', 'gb version', 'version ads', 'ads ads', 'ads big', 'big deal', 'deal figured', 'pass screen', 'screen matter', 'matter version', 'version pick', 'pick things', 'things gigs', 'gigs may', 'may may', 'may matter', 'matter gigs', 'gigs large', 'large want', 'want predownload', 'predownload tv', 'tv shows', 'shows movies', 'movies music', 'music vacation', 'vacation may', 'may want', 'want look', 'look getting', 'getting larger', 'larger gig', 'gig always', 'always internet', 'internet connection', 'connection much', 'much problem', 'unlimited cloud', 'cloud storage', 'storage download', 'download device', 'device stream', 'stream anytime', 'anytime internetoverall', 'internetoverall want', 'want amazon', 'amazon tablet', 'want best', 'best go', 'go hdx', 'hdx series', 'want amazing', 'amazing tablet', 'want spend', 'spend much', 'much new', 'new hd', 'hd series', 'series great', 'great uses', 'uses hd', 'hd perfect', 'perfect fiti', 'suggest buyers', 'buyers things', 'things larger', 'larger screen', 'screen dual', 'speakers sure', 'sure dual', 'speakers kind', 'kind nice', 'nice screen', 'screen actually', 'actually lower', 'lower quality', 'quality read', 'read low']
# Top freq words: ['apple tv', 'streaming content', 'roku boxes', 'roku box', 'app', 'amazon', 'smart tv', 'box really', 'prime streaming', 'means roku', 'box roku', 'firetv roku', 'netflix', 'fire tv', 'casual user', 'user ondemand', 'ondemand content', 'content devices', 'devices tried', 'tried smart', 'tv brands', 'brands smart', 'smart dvd', 'dvd bluray', 'bluray players', 'players apple', 'tv wdtv', 'wdtv htpc', 'htpc chromecast', 'chromecast many', 'many competing', 'competing products', 'products mentionfor', 'mentionfor streaming', 'content box', 'really two', 'two options', 'options simple', 'simple use', 'use box', 'box require', 'require additional', 'additional items', 'items tweaking', 'first apple', 'tv easy', 'easy use', 'use interface', 'interface apple', 'apple limits', 'limits content', 'greatly including', 'including prime', 'streaming built', 'built lacks', 'lacks lot', 'lot features', 'features well', 'well slow', 'slow reason', 'reason selecting', 'selecting apple', 'tv apple', 'apple products', 'products unlock', 'unlock features', 'second option', 'consider rokuwhich', 'rokuwhich really', 'really means', 'heads tails', 'tails better', 'better past', 'past roku', 'boxes terms', 'terms remote', 'remote speed', 'speed roku', 'roku stands', 'stands content', 'content features', 'features box', 'roku reason', 'reason see', 'see address', 'address roku', 'roku often', 'added quick', 'quick summaries', 'summaries options', 'options make', 'make sure', 'sure everyone', 'everyone knows', 'knows options', 'great streaming', 'content user', 'cheap requires', 'requires items', 'items use', 'use remote', 'remote included', 'included limited', 'limited channels', 'channels according', 'according site', 'site content', 'content broadcast', 'broadcast via', 'via chrome', 'chrome browser', 'browser quality', 'quality level', 'level allow', 'allow browse', 'browse internet', 'internet tv', 'tv amazing', 'amazing cost', 'cost niche', 'niche market', 'market firetv', 'roku apple', 'tv live', 'live short', 'short comings', 'comings worth', 'worth look', 'look price', 'tweaking first', 'amazon contentthe', 'contentthe second', 'often reviewi', 'reviewi added', 'options therewdtv', 'therewdtv great', 'user friendlychromecast', 'friendlychromecast cheap', 'price devicessmart', 'devicessmart tvs', 'tvs fine', 'fine occasional', 'occasional use', 'use nearly', 'nearly pleasant', 'pleasant use', 'use daily', 'separate boxesread', 'boxesread casual', 'game', 'said', 'work', 'play', 'instead', 'voice search', 'something', 'time', 'one', 'gaming', 'fast', 'vevo', 'missing', 'seem', 'button', 'much', 'less', 'console', 'performance', 'back', 'feel', 'people', 'hbo go', 'video', 'add', 'everything', 'honestly', 'best', 'using', 'even', 'hdmi', 'used', 'personally', 'update', 'comments', 'episode', 'show', 'decent', 'without', 'changed', 'new', 'right', 'processor', 'real', 'noticed', 'different', 'cable', 'simply', 'pretty', 'fact', 'tell']
# Top freq words: ['comcast ondemand', 'typical middleaged', 'middleaged woman', 'woman game', 'super techsavvy', 'techsavvy meansso', 'meansso take', 'take review', 'review fire', 'fire tv', 'tv easy', 'easy install', 'loving features', 'features free', 'free movies', 'movies music', 'music simple', 'simple interface', 'interface thing', 'thing even', 'even screen', 'screen saver', 'saver comes', 'comes listening', 'listening music', 'always comcast', 'comcast cable', 'cable service', 'service without', 'without dvr', 'dvr occasionally', 'occasionally used', 'used comcast', 'ondemand watch', 'watch rent', 'rent movies', 'never watch', 'watch comcast', 'comcast voice', 'voice recognition', 'recognition software', 'software amazing', 'amazing brought', 'brought exactly', 'exactly looking', 'looking every', 'every single', 'single time', 'time searched', 'searched easy', 'easy find', 'find looking', 'looking unlike', 'unlike comcast', 'amazon prime', 'prime member', 'member want', 'want view', 'view free', 'free oh', 'oh new', 'new release', 'release movies', 'movies cost', 'cost rent', 'rent amazon', 'amazon average', 'average cheaper', 'cheaper comcast', 'ondemand happy', 'happy purchase']

# %% [markdown]
# # Bonus 1: Extra data pre-processing

# %%
df['prices'] = df['prices'].apply(ast.literal_eval)
df_prices = df.explode('prices')
df_parsed = df_prices['prices'].apply(pd.Series)
# df_parsed
df_final = pd.concat([df.drop(columns=['prices']), df_parsed], axis=1)

# %%
df_parsed.head()
# Out:
#    amountMax  amountMin currency             dateAdded  \
# 0     139.99     139.99      USD  2017-07-18T23:52:58Z
# 0     119.99     119.99      EUR  2016-03-08T20:21:53Z
# 0     139.99     139.99      CAD  2016-03-08T20:21:53Z
# 0     119.99     119.99      USD  2016-03-08T20:21:53Z
# 0     119.99     119.99      EUR  2016-03-08T20:21:53Z
#
#                                            dateSeen isSale        merchant  \
# 0  [2017-07-15T18:10:23.807Z, 2016-03-16T00:00:00Z]  false      Amazon.com
# 0                            [2016-01-29T00:00:00Z]  false  Amazon EU Sarl
# 0                            [2016-01-11T00:00:00Z]  false          Amazon
# 0                            [2016-03-12T00:00:00Z]   true      Amazon.com
# 0                            [2015-11-15T00:00:00Z]  false          Amazon
#
#          shipping                                         sourceURLs  \
# 0  FREE Shipping.  [https://www.amazon.com/Kindle-Paperwhite-High...
# 0            free  [http://www.amazon.co.uk/Kindle-Paperwhite-Res...
# 0            free               [http://www.amazon.ca/dp/B00QJDU3KY]
# 0             NaN  [http://www.amazon.com/Kindle-Paperwhite-High-...
# 0            free  [http://www.amazon.co.uk/All-New-Kindle-Paperw...
#
#   condition availability offer returnPolicy warranty
# 0       NaN          NaN   NaN          NaN      NaN
# 0       new          NaN   NaN          NaN      NaN
# 0       new          NaN   NaN          NaN      NaN
# 0       NaN          NaN   NaN          NaN      NaN
# 0       new          NaN   NaN          NaN      NaN

# %%
df_final.groupby('isSale').agg(avg_rating=('reviews.rating','mean'))
# Out:
#         avg_rating
# isSale
# false     4.417196
# true      4.362576

# %%
df_final.groupby('merchant').agg(avg_rating=('reviews.rating','mean')).sort_values(by='avg_rating',ascending=False)
# Out:
#                         avg_rating
# merchant
# Amazon.ca                 4.666667
# Bestbuy.com               4.533210
# Kmart                     4.533210
# homedepot.com             4.533210
# Amazon.com                4.472057
# Amazon                    4.202899
# Amazon EU Sarl            4.166667
# Tech2Date                 4.012987
# easy-to-open packaging    3.885870
# MobileRush                3.333333

# %%
df_final.groupby('shipping').agg(avg_rating=('reviews.rating','mean')).sort_values(by='avg_rating',ascending=False)
# Out:
#                                                     avg_rating
# shipping
# FREE Shipping.                                        4.428363
# free                                                  4.236111
# FREE                                                  4.204545
# USD 5.99                                              4.204545
# FREE Shipping on orders over USD 25.00                4.125628
# FREE Shipping                                         4.012987
# FREE Shipping on eligible orders.                     4.012987
# FREE Shipping on orders over USD 25or get FREE ...    4.012987
# FREE Shipping on orders over USD 35.00                4.012987
# Value                                                 4.012987
# Free Shipping for Prime Members Fast, FREE Ship...    2.708333

# %%
df1.head()
# Out:
#                       id       asins   brand  \
# 56  AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
# 59  AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
# 60  AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
# 62  AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
# 63  AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
#
#                                            categories colors  \
# 56  Categories,Amazon Devices,Streaming Media Players    NaN
# 59  Categories,Amazon Devices,Streaming Media Players    NaN
# 60  Categories,Amazon Devices,Streaming Media Players    NaN
# 62  Categories,Amazon Devices,Streaming Media Players    NaN
# 63  Categories,Amazon Devices,Streaming Media Players    NaN
#
#                dateAdded           dateUpdated dimension           ean  \
# 56  2016-02-03T04:11:33Z  2017-08-08T22:03:27Z       NaN  8.487190e+11
# 59  2016-02-03T04:11:33Z  2017-08-08T22:03:27Z       NaN  8.487190e+11
# 60  2016-02-03T04:11:33Z  2017-08-08T22:03:27Z       NaN  8.487190e+11
# 62  2016-02-03T04:11:33Z  2017-08-08T22:03:27Z       NaN  8.487190e+11
# 63  2016-02-03T04:11:33Z  2017-08-08T22:03:27Z       NaN  8.487190e+11
#
#                                                  keys  ...  \
# 56  848719035551,0848719035551,certifiedrefurbishe...  ...
# 59  848719035551,0848719035551,certifiedrefurbishe...  ...
# 60  848719035551,0848719035551,certifiedrefurbishe...  ...
# 62  848719035551,0848719035551,certifiedrefurbishe...  ...
# 63  848719035551,0848719035551,certifiedrefurbishe...  ...
#
#                                         reviews.title reviews.userCity  \
# 56  A review from a non-techie 11,059 people found...              NaN
# 59  A review from a non-techie 11,064 people found...              NaN
# 60  This box is a GAME CHANGER for on demand conte...              NaN
# 62  A review from a non-techie 11,061 people found...              NaN
# 63  A review from a non-techie 11,064 people found...              NaN
#
#    reviews.userProvince reviews.username sizes           upc  weight  \
# 56                  NaN            Mandy   NaN  8.487190e+11     NaN
# 59                  NaN            Mandy   NaN  8.487190e+11     NaN
# 60                  NaN   William Hardin   NaN  8.487190e+11     NaN
# 62                  NaN            Mandy   NaN  8.487190e+11     NaN
# 63                  NaN            Mandy   NaN  8.487190e+11     NaN
#
#                                            title_text  \
# 56  review nontechie people found helpful review h...
# 59  review nontechie people found helpful review h...
# 60  box game changer demand content amazon knocked...
# 62  review nontechie people found helpful review h...
# 63  review nontechie people found helpful review h...
#
#                                             embedding clusters_fast
# 56  [-0.058856953, -0.2832943, 0.24210207, -0.2186...             7
# 59  [-0.058856953, -0.2832943, 0.24210207, -0.2186...             7
# 60  [-0.09482231, 0.014757549, -0.17202933, -0.229...             6
# 62  [-0.058856953, -0.2832943, 0.24210207, -0.2186...             7
# 63  [-0.058856953, -0.2832943, 0.24210207, -0.2186...             7
#
# [5 rows x 30 columns]

# %% [markdown]
# # Bonus 2: Fine Tune with LLM Embeddings

# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np

# %%
# Assuming 'df1' is your DataFrame

# Step 1: Extract the embeddings
# Convert the 'embedding' column (which contains lists) into a numpy array
embeddings = np.array(df1['embedding'].tolist())

# Step 2: Apply KMeans
# Specify the number of clusters (you can adjust 'n_clusters' as needed)
kmeans = KMeans(n_clusters=8, random_state=42)
df1['kmeans_cluster'] = kmeans.fit_predict(embeddings)

# Step 3: Add the cluster labels to the DataFrame
print(df1[['embedding', 'kmeans_cluster']].head())

# Now the 'kmeans_cluster' column will have the cluster label for each row
# Out:
#                                             embedding  kmeans_cluster
# 56  [-0.058856953, -0.2832943, 0.24210207, -0.2186...               7
# 59  [-0.058856953, -0.2832943, 0.24210207, -0.2186...               7
# 60  [-0.09482231, 0.014757549, -0.17202933, -0.229...               3
# 62  [-0.058856953, -0.2832943, 0.24210207, -0.2186...               7
# 63  [-0.058856953, -0.2832943, 0.24210207, -0.2186...               7

# %% [markdown]
# # Bonus 3: Sentiment Modeling

# %%
from textblob import TextBlob

# Function to calculate sentiment polarity (ranges from -1 to 1)
def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

# Apply sentiment analysis to the reviews' text (assuming 'title_text' is the review text)
df1['sentiment'] = df1['title_text'].apply(get_sentiment)

# Classify sentiment as Positive, Neutral, or Negative
df1['sentiment_label'] = df1['sentiment'].apply(lambda x: 'positive' if x > 0 else ('negative' if x < 0 else 'neutral'))

# Inspect the results
print(df1[['title_text', 'sentiment', 'sentiment_label']].head())
# Out:
#                                            title_text  sentiment  \
# 56  review nontechie people found helpful review h...   0.224892
# 59  review nontechie people found helpful review h...   0.224892
# 60  box game changer demand content amazon knocked...   0.191730
# 62  review nontechie people found helpful review h...   0.224892
# 63  review nontechie people found helpful review h...   0.224892
#
#    sentiment_label
# 56        positive
# 59        positive
# 60        positive
# 62        positive
# 63        positive

# %%
cluster_sentiment = df1.groupby(['kmeans_cluster', 'sentiment_label']).size().unstack(fill_value=0)

# Display the number of positive, negative, and neutral reviews per cluster
print(cluster_sentiment)

# Plotting for better visualization (optional)
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap to visualize the sentiment distribution in each cluster
sns.heatmap(cluster_sentiment, annot=True, cmap="coolwarm")
plt.title('Sentiment Distribution Across Clusters')
plt.ylabel('Cluster')
plt.xlabel('Sentiment')
plt.show()
# Out:
# sentiment_label  positive
# kmeans_cluster
# 0                      28
# 1                      59
# 2                      43
# 3                      27
# 4                      29
# 5                      30
# 6                      31
# 7                      26
